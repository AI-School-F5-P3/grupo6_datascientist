# %%
pip install imbalanced-learn
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.1 -> 24.2
# [notice] To update, run: C:\Users\Administrator\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: imbalanced-learn in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (0.12.4)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from imbalanced-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from imbalanced-learn) (1.13.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from imbalanced-learn) (1.5.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from imbalanced-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from imbalanced-learn) (3.5.0)

# %%
# !pip install ydata_profiling
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ydata_profiling in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (4.10.0)
# Requirement already satisfied: scipy<1.14,>=1.4.1 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ydata_profiling) (1.13.1)
# Requirement already satisfied: pandas!=1.4.0,<3,>1.1 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ydata_profiling) (2.2.2)
# Requirement already satisfied: matplotlib<3.10,>=3.5 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ydata_profiling) (3.9.2)
# Requirement already satisfied: pydantic>=2 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ydata_profiling) (2.8.2)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ydata_profiling) (6.0.1)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ydata_profiling) (3.1.4)
# Requirement already satisfied: visions<0.7.7,>=0.7.5 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from visions[type_image_path]<0.7.7,>=0.7.5->ydata_profiling) (0.7.6)
# Requirement already satisfied: numpy<2.2,>=1.16.0 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ydata_profiling) (2.0.2)
# Requirement already satisfied: htmlmin==0.1.12 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ydata_profiling) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ydata_profiling) (0.12.4)
# Requirement already satisfied: requests<3,>=2.24.0 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ydata_profiling) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4.48.2 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ydata_profiling) (4.66.5)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ydata_profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ydata_profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ydata_profiling) (0.14.4)
# Requirement already satisfied: typeguard<5,>=3 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ydata_profiling) (4.3.0)
# Requirement already satisfied: imagehash==4.3.1 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ydata_profiling) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.3 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ydata_profiling) (1.9.3)
# Requirement already satisfied: dacite>=1.8 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ydata_profiling) (1.8.1)
# Requirement already satisfied: numba<1,>=0.56.0 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ydata_profiling) (0.60.0)
# Requirement already satisfied: PyWavelets in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from imagehash==4.3.1->ydata_profiling) (1.7.0)
# Requirement already satisfied: pillow in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from imagehash==4.3.1->ydata_profiling) (10.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jinja2<3.2,>=2.11.1->ydata_profiling) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib<3.10,>=3.5->ydata_profiling) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib<3.10,>=3.5->ydata_profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib<3.10,>=3.5->ydata_profiling) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib<3.10,>=3.5->ydata_profiling) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib<3.10,>=3.5->ydata_profiling) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib<3.10,>=3.5->ydata_profiling) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib<3.10,>=3.5->ydata_profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from numba<1,>=0.56.0->ydata_profiling) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas!=1.4.0,<3,>1.1->ydata_profiling) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas!=1.4.0,<3,>1.1->ydata_profiling) (2024.1)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from phik<0.13,>=0.11.1->ydata_profiling) (1.4.2)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pydantic>=2->ydata_profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pydantic>=2->ydata_profiling) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pydantic>=2->ydata_profiling) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests<3,>=2.24.0->ydata_profiling) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests<3,>=2.24.0->ydata_profiling) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests<3,>=2.24.0->ydata_profiling) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests<3,>=2.24.0->ydata_profiling) (2024.6.2)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from statsmodels<1,>=0.13.2->ydata_profiling) (0.5.6)
# Requirement already satisfied: colorama in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tqdm<5,>=4.48.2->ydata_profiling) (0.4.6)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata_profiling) (23.2.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata_profiling) (3.3)
# Requirement already satisfied: six in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from patsy>=0.5.6->statsmodels<1,>=0.13.2->ydata_profiling) (1.16.0)
# [notice] A new release of pip is available: 24.1 -> 24.2
# [notice] To update, run: C:\Users\Administrator\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# !pip install optuna
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: optuna in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (4.0.0)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from optuna) (1.13.2)
# Requirement already satisfied: colorlog in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from optuna) (6.8.2)
# Requirement already satisfied: numpy in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from optuna) (24.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from optuna) (2.0.31)
# Requirement already satisfied: tqdm in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from optuna) (4.66.5)
# Requirement already satisfied: PyYAML in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from optuna) (6.0.1)
# Requirement already satisfied: Mako in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from alembic>=1.5.0->optuna) (1.3.5)
# Requirement already satisfied: typing-extensions>=4 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from sqlalchemy>=1.3.0->optuna) (3.0.3)
# Requirement already satisfied: colorama in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from colorlog->optuna) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\administrator\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.5)
# [notice] A new release of pip is available: 24.1 -> 24.2
# [notice] To update, run: C:\Users\Administrator\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from ydata_profiling import ProfileReport
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import optuna
import xgboost as xgb
from sklearn.metrics import f1_score
from sklearn.ensemble import VotingClassifier
from imblearn.over_sampling import SMOTE
from imblearn.ensemble import EasyEnsembleClassifier
from sklearn.preprocessing import OneHotEncoder
import pandas as pd

# %%
# Cargar el dataset
df = pd.read_csv('stroke_dataset.csv')

# Encoding variables binarias con LabelEncoder
label_encoder = LabelEncoder()
df['ever_married'] = label_encoder.fit_transform(df['ever_married'])
df['gender'] = label_encoder.fit_transform(df['gender'])

# Crear nuevas columnas categóricas y features adicionales

# 1. Grupos de edad
def age_group(age):
    if age <= 18:
        return '0-18'
    elif 19 <= age <= 35:
        return '19-35'
    elif 36 <= age <= 50:
        return '36-50'
    elif 51 <= age <= 65:
        return '51-65'
    else:
        return '65+'

df['age_group'] = df['age'].apply(age_group)

# 2. Combinación de hipertensión y enfermedades cardíacas
df['hypertension_heart_disease'] = ((df['hypertension'] == 1) & (df['heart_disease'] == 1)).astype(int)

# 3. Comorbilidades
df['comorbidities'] = df['hypertension'] + df['heart_disease']

# 4. Categorías de IMC
def bmi_category(bmi):
    if bmi < 18.5:
        return 'underweight'
    elif 18.5 <= bmi < 25:
        return 'normal'
    elif 25 <= bmi < 30:
        return 'overweight'
    else:
        return 'obese'

df['bmi_category'] = df['bmi'].apply(bmi_category)

# 5. Obesidad
df['obese'] = df['bmi'].apply(lambda x: 1 if x >= 30 else 0)

# 6. Fumador actual o pasado
df['smoker_status'] = df['smoking_status'].apply(lambda x: 1 if x in ['formerly smoked', 'smokes'] else 0)

# 7. Riesgo elevado
df['high_risk_lifestyle'] = ((df['smoker_status'] == 1) | (df['hypertension'] == 1) | (df['heart_disease'] == 1)).astype(int)

# 8. Glucosa elevada
df['high_glucose'] = df['avg_glucose_level'].apply(lambda x: 1 if x > 140 else 0)

# 9. Combinación de edad avanzada y comorbilidades
df['elderly_comorbid'] = ((df['age'] > 65) & (df['comorbidities'] > 0)).astype(int)

# Separar las características y el objetivo
y = df['stroke']
X = df.drop('stroke', axis=1)

# 1. Identificar columnas categóricas (incluyendo smoking_status)
categorical_cols = X.select_dtypes(include=['object', 'category']).columns

# 2. Aplicar OneHotEncoder a las variables categóricas
encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
encoded_data = encoder.fit_transform(X[categorical_cols])

# 3. Crear un DataFrame con las columnas codificadas
encoded_df = pd.DataFrame(encoded_data, columns=encoder.get_feature_names_out(categorical_cols))

# 4. Concatenar las columnas codificadas con las características numéricas
X_encoded = pd.concat([X.drop(categorical_cols, axis=1), encoded_df], axis=1)

# Dividir en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Calcular pesos de clase para manejar el desbalance
class_weights = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
class_weights_dict = {0: class_weights[0], 1: class_weights[1]}

# Ahora puedes usar X_train, X_test, y_train, y_test para entrenar tu modelo

# %% [markdown]
# # Optimización de hiperparámetros con Optuna

# %% [markdown]
# XGBoost

# %%
# Función objetivo para XGBoost
def objective_xgb(trial):
    param = {
        'verbosity': 0,
        'objective': 'binary:logistic',
        'eval_metric': 'logloss',
        'booster': 'gbtree',
        'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
        'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
        'colsample_bytree': trial.suggest_categorical('colsample_bytree', [0.5, 0.7, 1.0]),
        'subsample': trial.suggest_categorical('subsample', [0.5, 0.7, 1.0]),
        'learning_rate': trial.suggest_loguniform('learning_rate', 1e-8, 1.0),
        'n_estimators': trial.suggest_int('n_estimators', 50, 300),
        'max_depth': trial.suggest_int('max_depth', 3, 9),
        'random_state': 42,
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'scale_pos_weight': class_weights_dict[1]  # Aplicar el upweighting
    }

    # Convertir datos a DMatrix para XGBoost
    train_dmatrix = xgb.DMatrix(X_train, label=y_train)
    valid_dmatrix = xgb.DMatrix(X_test, label=y_test)

    # Entrenar el modelo
    xgb_clf = xgb.train(param, train_dmatrix)

    # Predecir en el conjunto de prueba
    preds = xgb_clf.predict(valid_dmatrix)
    pred_labels = np.rint(preds)

    # Evaluar la métrica objetivo (f1_score en este caso)
    score = f1_score(y_test, pred_labels)
    return score

# Iniciar el estudio de Optuna para XGBoost
study_xgb = optuna.create_study(direction="maximize")
study_xgb.optimize(objective_xgb, n_trials=100)

# Extraer los mejores hiperparámetros
best_params_xgb = study_xgb.best_trial.params
print("Best hyperparameters for XGBoost: ", best_params_xgb)
# Out:
# [I 2024-10-16 10:36:00,707] A new study created in memory with name: no-name-743d9f70-0ca9-4825-ae5b-f2dc3e3247f9
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-8, 1.0),
# [I 2024-10-16 10:36:00,832] Trial 0 finished with value: 0.0 and parameters: {'lambda': 0.0002637751701169119, 'alpha': 2.452886469210311e-05, 'colsample_bytree': 1.0, 'subsample': 0.5, 'learning_rate': 0.001281629158770003, 'n_estimators': 287, 'max_depth': 4, 'min_child_weight': 1}. Best is trial 0 with value: 0.0.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-8, 1.0),
# [I 2024-10-16 10:36:00,912] Trial 1 finished with value: 0.0 and parameters: {'lambda': 1.5097271719915534e-06, 'alpha': 0.6148857087826212, 'colsample_bytree': 1.0, 'subsample': 0.7, 'learning_rate': 0.001910286296458248, 'n_estimators': 163, 'max_depth': 9, 'min_child_weight': 7}. Best is trial 0 with value: 0.0.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-8, 1.0),
# [I 2024-10-16 10:36:00,970] Trial 2 finished with value: 0.0 and parameters: {'lambda': 3.469653891984943e-06, 'alpha': 0.010131123187527298, 'colsample_bytree': 1.0, 'subsample': 0.7, 'learning_rate': 1.7642207764530208e-05, 'n_estimators': 170, 'max_depth': 5, 'min_child_weight': 4}. Best is trial 0 with value: 0.0.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-8, 1.0),
# [I 2024-10-16 10:36:01,037] Trial 3 finished with value: 0.0 and parameters: {'lambda': 0.026850162112260125, 'alpha': 0.0009125379527701988, 'colsample_bytree': 0.5, 'subsample': 0.7, 'learning_rate': 5.1747744807158984e-06, 'n_estimators': 72, 'max_depth': 5, 'min_child_weight': 9}. Best is trial 0 with value: 0.0.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-8, 1.0),
# [I 2024-10-16 10:36:01,098] Trial 4 finished with value: 0.0 and parameters: {'lambda': 1.8400803295238247e-05, 'alpha': 9.606438302595248e-06, 'colsample_bytree': 0.5, 'subsample': 1.0, 'learning_rate': 2.161419645673484e-06, 'n_estimators': 115, 'max_depth': 3, 'min_child_weight': 2}. Best is trial 0 with value: 0.0.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-8, 1.0),
# [I 2024-10-16 10:36

# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-8, 1.0),
# [I 2024-10-16 10:36:04,124] Trial 29 finished with value: 0.0 and parameters: {'lambda': 9.517494733532654e-05, 'alpha': 5.090948006755249e-07, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.0015699053331159508, 'n_estimators': 273, 'max_depth': 7, 'min_child_weight': 7}. Best is trial 28 with value: 0.30303030303030304.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-8, 1.0),
# [I 2024-10-16 10:36:04,277] Trial 30 finished with value: 0.0 and parameters: {'lambda': 8.019842512970634e-07, 'alpha': 6.072765295623734e-08, 'colsample_bytree': 0.5, 'subsample': 0.7, 'learning_rate': 0.00397348557543175, 'n_estimators': 274, 'max_depth': 8, 'min_child_weight': 6}. Best is trial 28 with value: 0.30303030303030304.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-8, 1.0),
# [I 2024-10-16 10:36:04,433] Trial 31 finished with value: 0.3010752688172043 and parameters: {'lambda': 6.875347427810477e-08, 'alpha': 5.2294436281670134e-06, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.2649870838736963, 'n_estimators': 234, 'max_depth': 6, 'min_child_weight': 5}. Best is trial 28 with value: 0.30303030303030304.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-8, 1.0),
# [I 2024-10-16 10:36:04,618] Trial 32 finished with value: 0.25806451612903225 and parameters: {'lambda': 4.857423227121156e-08, 'alpha': 4.52935211283931e-06, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.11846599674363528, 'n_estimators': 241, 'max_depth': 6, 'min_child_weight': 5}. Best is trial 28 with value: 0.30303030303030304.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-8, 1.0),
# [I 2024-10-16 10:36:04,782] Trial 33 finished with value: 0.2802547770700637 and parameters: {'lambda': 1.4419394273633583e-07, 'alpha': 3.676785510994153e-05, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.30500870129255697, 'n_estimators': 212, 'max_depth': 9, 'min_child_weight': 6}. Best is trial 28 with value: 0.30303030303030304.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-8, 1.0),
# [I 2024-10-16 10:36:04,934] Trial 34 finished with value: 0.0 and parameters: {'lambda': 5.1501435104699746e-08, 'alpha': 3.42027819404549e-05, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.028996447916284793, 'n_estimators': 258, 'max_depth': 9, 'min_child_weight': 8}. Best is trial 28 with value: 0.30303030303030304.
# ...
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-8, 1.0),
# [I 2024-10-16 10:36:11,488] Trial 88 finished with value: 0.21428571428571427 and parameters: {'lambda': 9.404238864148575e-08, 'alpha': 0.00011371417846577584, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.24454177802528618, 'n_estimators': 98, 'max_depth': 7, 'min_child_weight': 4}. Best is trial 80 with value: 0.32.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-8, 1.0),
# [I 2024-10-16 10:36:11,672] Trial 89 finished with value: 0.25316455696202533 and parameters: {'lambda': 1.3298172950196083e-06, 'alpha': 2.6190977283806572e-05, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.7182090326804756, 'n_estimators': 279, 'max_depth': 6, 'min_child_weight': 6}. Best is trial 80 with value: 0.32.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-8, 1.0),
# [I 2024-10-16 10:36:11,830] Trial 90 finished with value: 0.0 and parameters: {'lambda': 4.978557136062068e-07, 'alpha': 7.586014579329985e-05, 'colsample_bytree': 1.0, 'subsample': 0.7, 'learning_rate': 0.02406227532193422, 'n_estimators': 271, 'max_depth': 3, 'min_child_weight': 9}. Best is trial 80 with value: 0.32.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-8, 1.0),
# [I 2024-10-16 10:36:11,965] Trial 91 finished with value: 0.2814070351758794 and parameters: {'lambda': 2.528900972116438e-08, 'alpha': 0.00019152243533666463, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.17321114198508705, 'n_estimators': 294, 'max_depth': 5, 'min_child_weight': 7}. Best is trial 80 with value: 0.32.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-8, 1.0),
# [I 2024-10-16 10:36:12,072] Trial 92 finished with value: 0.23684210526315788 and parameters: {'lambda': 3.470751544916929e-08, 'alpha': 6.0406741151737365e-06, 'colsample_bytree': 0.7, 'subsample': 1.0, 'learning_rate': 0.4096253989534014, 'n_estimators': 223, 'max_depth': 4, 'min_child_weight': 7}. Best is trial 80 with value: 0.32.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-8, 1.0),
# [I 2024-10-16 10:36:12,187] Trial 93 finished with value: 0.16091954022988506 and parameters: {'lambda': 1.4639741233881125e-08, 'alpha': 6.20877105782908e-07, 'colsample_bytree': 0.7, 'subsample': 0.5, 'learning_rate': 0.06902915204040216, 'n_estimators': 50, 'max_depth': 5, 'min_child_weight': 8}. Best is trial 80 with value: 0.32.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-8, 1.0),
# [I 2024-10-16 10:36:12,314] Trial 94 finished with value: 0.267515923566879 and parameters: {'lambda': 0.00471667458134176, 'alpha': 1.1154873419255828e-05, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.13277342089440552, 'n_estimators': 198, 'max_depth': 6, 'min_child_weight': 6}. Best is trial 80 with value: 0.32.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-8, 1.0),
# [I 2024-10-16 10:36:12,430] Trial 95 finished with value: 0.2731707317073171 and parameters: {'lambda': 1.2582357730054344e-07, 'alpha': 1.5472058512604316e-06, 'colsample_bytree': 0.7, 'subsample': 1.0, 'learning_rate': 0.22171247652192425, 'n_estimators': 217, 'max_depth': 5, 'min_child_weight': 7}. Best is trial 80 with value: 0.32.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-8, 1.0),
# [I 2024-10-16 10:36:12,539] Trial 96 finished with value: 0.0 and parameters: {'lambda': 2.2164575652239917e-08, 'alpha': 8.092874484449574e-05, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 3.4635259191179095e-05, 'n_estimators': 184, 'max_depth': 4, 'min_child_weight': 5}. Best is trial 80 with value: 0.32.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-8, 1.0),
# [I 2024-10-16 10:36:12,651] Trial 97 finished with value: 0.0 and parameters: {'lambda': 6.277461230508475e-08, 'alpha': 4.260245608414507e-06, 'colsample_bytree': 0.7, 'subsample': 1.0, 'learning_rate': 0.036515870456984234, 'n_estimators': 203, 'max_depth': 7, 'min_child_weight': 7}. Best is trial 80 with value: 0.32.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-8, 1.0),
# [I 2024-10-16 10:36:12,758] Trial 98 finished with value: 0.19 and parameters: {'lambda': 1.9688011926629097e-07, 'alpha': 0.001090627311903083, 'colsample_bytree': 0.5, 'subsample': 0.7, 'learning_rate': 0.9646085205792994, 'n_estimators': 259, 'max_depth': 5, 'min_child_weight': 4}. Best is trial 80 with value: 0.32.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8592\1482579381.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-8, 1.0),
# [I 2024-10-16 10:36:12,876] Trial 99 finished with value: 0.1875 and parameters: {'lambda': 3.766507437551253e-08, 'alpha': 0.0005305969154917575, 'colsample_bytree': 0.7, 'subsample': 0.5, 'learning_rate': 0.08518205510065226, 'n_estimators': 210, 'max_depth': 8, 'min_child_weight': 8}. Best is trial 80 with value: 0.32.
# Best hyperparameters for XGBoost:  {'lambda': 1.7150608101583486e-07, 'alpha': 8.495865316200164e-05, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.15023631894267453, 'n_estimators': 266, 'max_depth': 6, 'min_child_weight': 7}

# %% [markdown]
# Regresión lineal

# %% [markdown]
# #Entrenamiento del modelo

# %%
# Entrenar el modelo XGBoost con los mejores hiperparámetros
xgb_model_optimized = xgb.XGBClassifier(**best_params_xgb)
xgb_model_optimized.fit(X_train, y_train)

# Predecir en el conjunto de prueba
y_pred_xgb_optimized = xgb_model_optimized.predict(X_test)

# Evaluar el rendimiento del modelo optimizado
from sklearn.metrics import classification_report

# %%
# Extraer importancias
importances = xgb_model_optimized.feature_importances_

# Crear un DataFrame para visualizar las importancias
feature_importances = pd.DataFrame({
    'Feature': X_train.columns,
    'Importance': importances
})

# Ordenar las características por importancia
feature_importances = feature_importances.sort_values(by='Importance', ascending=False)
print("Importancia de las características:")
print(feature_importances)
# Out:
# Importancia de las características:
#                            Feature  Importance
# 28                   age_group_65+    0.093819
# 25                 age_group_19-35    0.083634
# 1                              age    0.044547
# 4                     ever_married    0.043095
# 24                  age_group_0-18    0.041301
# 2                     hypertension    0.037956
# 27                 age_group_51-65    0.037771
# 26                 age_group_36-50    0.032853
# 8                    comorbidities    0.032503
# 15               work_type_Private    0.030346
# 5                avg_glucose_level    0.030319
# 6                              bmi    0.030116
# 30              bmi_category_obese    0.029889
# 22     smoking_status_never smoked    0.029653
# 16         work_type_Self-employed    0.029330
# 31         bmi_category_overweight    0.027599
# 3                    heart_disease    0.027180
# 21  smoking_status_formerly smoked    0.026994
# 14              work_type_Govt_job    0.026599
# 29             bmi_category_normal    0.026153
# 0                           gender    0.025914
# 11             high_risk_lifestyle    0.025685
# 19            Residence_type_Urban    0.024808
# 9                            obese    0.024713
# 10                   smoker_status    0.023727
# 20          smoking_status_Unknown    0.023640
# 12                    high_glucose    0.023391
# 13                elderly_comorbid    0.023017
# 18            Residence_type_Rural    0.021787
# 23           smoking_status_smokes    0.021662
# 7       hypertension_heart_disease    0.000000
# 17              work_type_children    0.000000
# 32        bmi_category_underweight    0.000000

# %%
# Seleccionar las 5 características más importantes
top_n = 5  # Cambia este valor según lo que desees
important_features = feature_importances.head(top_n)['Feature'].tolist()

# Filtrar los conjuntos de datos
X_train_important = X_train[important_features]
X_test_important = X_test[important_features]

import numpy as np
from sklearn.metrics import classification_report

# Entrenar el modelo XGBoost
xgb_model_optimized = xgb.XGBClassifier(**best_params_xgb)
xgb_model_optimized.fit(X_train_important, y_train)

# Obtener las probabilidades de las predicciones
y_prob_xgb_optimized = xgb_model_optimized.predict_proba(X_test_important)[:, 1]

# Definir un nuevo umbral
new_threshold = 0.165  # Ajusta este valor según sea necesario

# Clasificar las predicciones basadas en el nuevo umbral
y_pred_xgb_adjusted = (y_prob_xgb_optimized >= new_threshold).astype(int)

# Evaluar el rendimiento del modelo con el nuevo umbral
print("\nXGBoost Classification Report with Adjusted Threshold:")
print(classification_report(y_test, y_pred_xgb_adjusted))

from sklearn.metrics import accuracy_score

# Predecir en el conjunto de entrenamiento
y_pred_train = xgb_model_optimized.predict(X_train_important)

# Calcular la precisión en el conjunto de entrenamiento
accuracy_train = accuracy_score(y_train, y_pred_train)

# Calcular la precisión en el conjunto de prueba con el nuevo umbral
accuracy_test = accuracy_score(y_test, y_pred_xgb_adjusted)

# Calcular el porcentaje de overfitting
overfitting_percentage = (accuracy_train - accuracy_test) / accuracy_train * 100

# Imprimir los resultados
print(f"Accuracy en el conjunto de entrenamiento: {accuracy_train:.2f}")
print(f"Accuracy en el conjunto de prueba: {accuracy_test:.2f}")
print(f"Porcentaje de overfitting: {overfitting_percentage:.2f}%")
# Out:
# XGBoost Classification Report with Adjusted Threshold:
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95       943
#            1       0.16      0.19      0.17        54
#
#     accuracy                           0.90       997
#    macro avg       0.56      0.56      0.56       997
# weighted avg       0.91      0.90      0.91       997
#
# Accuracy en el conjunto de entrenamiento: 0.95
# Accuracy en el conjunto de prueba: 0.90
# Porcentaje de overfitting: 5.11%

# %% [markdown]
# A PARTIR DE AQUÍ SON PRUEBAS :)

# %%
import pickle

# Guardar el modelo XGBoost entrenado en un archivo pickle
with open('xgb_model_optimized2.pkl', 'wb') as file:
    pickle.dump(xgb_model_optimized, file)

print("Modelo XGBoost guardado exitosamente en 'xgb_model_optimized.pkl'")
# Out:
# Modelo XGBoost guardado exitosamente en 'xgb_model_optimized.pkl'

# %%
import pickle
from sklearn.metrics import classification_report, accuracy_score

# Cargar el modelo desde el archivo pickle
with open('xgb_model_optimized_1.pkl', 'rb') as file:
    loaded_model = pickle.load(file)

# Obtener las probabilidades de las predicciones
y_prob_xgb = loaded_model.predict_proba(X_test_important)[:, 1]

# Definir un nuevo umbral
new_threshold = 0.165  # Ajusta este valor según sea necesario

# Clasificar las predicciones basadas en el nuevo umbral
y_pred_loaded_model = (y_prob_xgb >= new_threshold).astype(int)

# Evaluar el rendimiento del modelo cargado
accuracy = accuracy_score(y_test, y_pred_loaded_model)
print(f"Accuracy del modelo cargado: {accuracy:.4f}")

# Imprimir el informe de clasificación
print("\nClassification Report del modelo cargado:")
print(classification_report(y_test, y_pred_loaded_model))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 9
#       6     loaded_model = pickle.load(file)
#       8 # Obtener las probabilidades de las predicciones
# ----> 9 y_prob_xgb = loaded_model.predict_proba(X_test_important)[:, 1]
#      11 # Definir un nuevo umbral
#      12 new_threshold = 0.165  # Ajusta este valor según sea necesario
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\sklearn.py:1644, in XGBClassifier.predict_proba(self, X, validate_features, base_margin, iteration_range)
#    1642     class_prob = softmax(raw_predt, axis=1)
#    1643     return class_prob
# -> 1644 class_probs = super().predict(
#    1645     X=X,
#    1646     validate_features=validate_features,
#    1647     base_margin=base_margin,
#    1648     iteration_range=iteration_range,
#    1649 )
#    1650 return _cls_predict_proba(self.n_classes_, class_probs, np.vstack)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\sklearn.py:1186, in XGBModel.predict(self, X, output_margin, validate_features, base_margin, iteration_range)
#    1184 if self._can_use_inplace_predict():
#    1185     try:
# -> 1186         predts = self.get_booster().inplace_predict(
#    1187             data=X,
#    1188             iteration_range=iteration_range,
#    1189             predict_type="margin" if output_margin else "value",
#    1190             missing=self.missing,
#    1191             base_margin=base_margin,
#    1192             validate_features=validate_features,
#    1193         )
#    1194         if _is_cupy_alike(predts):
#    1195             import cupy  # pylint: disable=import-error
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:2510, in Booster.inplace_predict(self, data, iteration_range, predict_type, missing, validate_features, base_margin, strict_shape)
#    2508     data, fns, _ = _transform_pandas_df(data, enable_categorical)
#    2509     if validate_features:
# -> 2510         self._validate_features(fns)
#    2511 if _is_list(data) or _is_tuple(data):
#    2512     data = np.array(data)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:3075, in Booster._validate_features(self, feature_names)
#    3069 if my_missing:
#    3070     msg += (
#    3071         "\ntraining data did not have the following fields: "
#    3072         + ", ".join(str(s) for s in my_missing)
#    3073     )
# -> 3075 raise ValueError(msg.format(self.feature_names, feature_names))
#
# ValueError: feature_names mismatch: ['age', 'elderly_comorbid', 'hypertension', 'work_type_Private', 'smoking_status_never smoked'] ['age_group_65+', 'age_group_19-35', 'age', 'ever_married', 'age_group_0-18']
# expected elderly_comorbid, work_type_Private, smoking_status_never smoked, hypertension in input data
# training data did not have the following fields: age_group_19-35, age_group_0-18, ever_married, age_group_65+

# %%
print(X_train.columns.tolist())  # Lista de columnas del conjunto de entrenamiento
# Out:
# ['gender', 'age', 'hypertension', 'heart_disease', 'ever_married', 'avg_glucose_level', 'bmi', 'hypertension_heart_disease', 'comorbidities', 'obese', 'smoker_status', 'high_risk_lifestyle', 'high_glucose', 'elderly_comorbid', 'work_type_Govt_job', 'work_type_Private', 'work_type_Self-employed', 'work_type_children', 'Residence_type_Rural', 'Residence_type_Urban', 'smoking_status_Unknown', 'smoking_status_formerly smoked', 'smoking_status_never smoked', 'smoking_status_smokes', 'age_group_0-18', 'age_group_19-35', 'age_group_36-50', 'age_group_51-65', 'age_group_65+', 'bmi_category_normal', 'bmi_category_obese', 'bmi_category_overweight', 'bmi_category_underweight']

# %%
print(X_test_important.columns.tolist())  # Lista de columnas del conjunto de prueba
# Out:
# ['age_group_19-35', 'age_group_0-18', 'age_group_65+', 'age', 'ever_married']
